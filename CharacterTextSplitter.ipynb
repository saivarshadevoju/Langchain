# %% [markdown]
# # Character Text Splitter

# %% [markdown]
# This is the simplest method. This splits based on a given character sequence, which defaults to "\n\n". Chunk length is measured by number of characters.
#
# 1. How the text is split: by single character separator.
# 2. How the chunk size is measured: by number of characters.
#
# How it works
# Suppose the separator is:
# "\n\n"
#
# That means:
# split text wherever there is a paragraph break

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader('./speech.txt')
text = loader.load()
text
# Out:
# [Document(metadata={'source': './speech.txt'}, page_content='Good Morning Everyone,\n\nMy name is Sai Varsha, and today I am going to speak about Artificial Intelligence, commonly known as AI.\n\nArtificial Intelligence is one of the most powerful and rapidly growing technologies in the world today. AI refers to machines or computer systems that can perform tasks which usually require human intelligence, such as learning, problem-solving, decision-making, speech recognition, and image understanding.\n\nToday, AI is becoming a part of our daily lives. When we use voice assistants like Google Assistant or Siri, get recommendations on Netflix or YouTube, or use navigation apps like Google Maps, we are actually using AI.\n\nAI is helping many industries grow faster and smarter. In healthcare, it helps doctors detect diseases early. In education, AI-powered tools make learning easier and more personalized. In agriculture, AI helps farmers monitor crops and improve production. Even in banking, transportation, and cybersecurity, AI plays a major role.\n\nOne of the biggest advantages of AI is that it can complete tasks faster, reduce human errors, and save time. It can analyze huge amounts of data within seconds and provide accurate results.\n\nHowever, AI also has some challenges. Excessive dependence on AI may reduce human creativity and can affect jobs in certain sectors. Therefore, AI should be used responsibly and ethically for the betterment of society.\n\nIn my opinion, AI is not here to replace humans completely, but to assist humans and make our lives easier. The future of AI is very exciting, and it will continue to transform the world in many ways.\n\nSo, instead of fearing AI, we should learn about it, adapt to it, and use it wisely.\n\nThank you everyone. Have a great day!\n')]

# %%
from langchain_text_splitters import CharacterTextSplitter 
splitter = CharacterTextSplitter(chunk_size=100, chunk_overlap=0)
chunks = splitter.split_documents(text)
chunks
# Out:
# Created a chunk of size 105, which is longer than the specified 100
# Created a chunk of size 308, which is longer than the specified 100
# Created a chunk of size 218, which is longer than the specified 100
# Created a chunk of size 330, which is longer than the specified 100
# Created a chunk of size 190, which is longer than the specified 100
# Created a chunk of size 218, which is longer than the specified 100
# Created a chunk of size 200, which is longer than the specified 100
# [Document(metadata={'source': './speech.txt'}, page_content='Good Morning Everyone,'),
#  Document(metadata={'source': './speech.txt'}, page_content='My name is Sai Varsha, and today I am going to speak about Artificial Intelligence, commonly known as AI.'),
#  Document(metadata={'source': './speech.txt'}, page_content='Artificial Intelligence is one of the most powerful and rapidly growing technologies in the world today. AI refers to machines or computer systems that can perform tasks which usually require human intelligence, such as learning, problem-solving, decision-making, speech recognition, and image understanding.'),
#  Document(metadata={'source': './speech.txt'}, page_content='Today, AI is becoming a part of our daily lives. When we use voice assistants like Google Assistant or Siri, get recommendations on Netflix or YouTube, or use navigation apps like Google Maps, we are actually using AI.'),
#  Document(metadata={'source': './speech.txt'}, page_content='AI is helping many industries grow faster and smarter. In healthcare, it helps doctors detect diseases early. In education, AI-powered tools make learning easier and more personalized. In agriculture, AI helps farmers monitor crops and improve production. Even in banking, transportation, and cybersecurity, AI plays a major role.'),
#  Document(metadata={'source': './speech.txt'}, page_content='One of the biggest advantages of AI is that it can complete tasks faster, reduce human errors, and save time. It can analyze huge amounts of data within seconds and provide accurate results.'),
#  Document(metadata={'source': './speech.txt'}, page_content='However, AI also has some challenges. Excessive dependence on AI may reduce human creativity and can affect jobs in certain sectors. Therefore, AI should be used responsibly and ethically for the betterment of society.'),
#  Document(metadata={'source': './speech.txt'}, page_content='In my opinion, AI is not here to replace humans completely, but to assist humans and make our lives easier. The future of AI is very exciting, and it will continue to transform the world in many ways.'),
#  Document(metadata={'source': './speech.txt'}, page_content='So, instead of fearing AI, we should learn about it, adapt to it, and use it wisely.'),
#  Document(metadata={'source': './speech.txt'}, page_content='Thank you everyone. Have a great day!')]

# %%
with open('speech.txt', 'r') as file:
    content = file.read()
    print(content)

splitter = CharacterTextSplitter(chunk_size=100, chunk_overlap=0)
chunks = splitter.split_text(content)
chunks
# Out:
# Created a chunk of size 105, which is longer than the specified 100
# Created a chunk of size 308, which is longer than the specified 100
# Created a chunk of size 218, which is longer than the specified 100
# Created a chunk of size 330, which is longer than the specified 100
# Created a chunk of size 190, which is longer than the specified 100
# Created a chunk of size 218, which is longer than the specified 100
# Created a chunk of size 200, which is longer than the specified 100
# Good Morning Everyone,
#
# My name is Sai Varsha, and today I am going to speak about Artificial Intelligence, commonly known as AI.
#
# Artificial Intelligence is one of the most powerful and rapidly growing technologies in the world today. AI refers to machines or computer systems that can perform tasks which usually require human intelligence, such as learning, problem-solving, decision-making, speech recognition, and image understanding.
#
# Today, AI is becoming a part of our daily lives. When we use voice assistants like Google Assistant or Siri, get recommendations on Netflix or YouTube, or use navigation apps like Google Maps, we are actually using AI.
#
# AI is helping many industries grow faster and smarter. In healthcare, it helps doctors detect diseases early. In education, AI-powered tools make learning easier and more personalized. In agriculture, AI helps farmers monitor crops and improve production. Even in banking, transportation, and cybersecurity, AI plays a major role.
#
# One of the biggest advantages of AI is that it can complete tasks faster, reduce human errors, and save time. It can analyze huge amounts of data within seconds and provide accurate results.
#
# However, AI also has some challenges. Excessive dependence on AI may reduce human creativity and can affect jobs in certain sectors. Therefore, AI should be used responsibly and ethically for the betterment of society.
#
# In my opinion, AI is not here to replace humans completely, but to assist humans and make our lives easier. The future of AI is very exciting, and it will continue to transform the world in many ways.
#
# So, instead of fearing AI, we should learn about it, adapt to it, and use it wisely.
#
# Thank you everyone. Have a great day!
# ['Good Morning Everyone,',
#  'My name is Sai Varsha, and today I am going to speak about Artificial Intelligence, commonly known as AI.',
#  'Artificial Intelligence is one of the most powerful and rapidly growing technologies in the world today. AI refers to machines or computer systems that can perform tasks which usually require human intelligence, such as learning, problem-solving, decision-making, speech recognition, and image understanding.',
#  'Today, AI is becoming a part of our daily lives. When we use voice assistants like Google Assistant or Siri, get recommendations on Netflix or YouTube, or use navigation apps like Google Maps, we are actually using AI.',
#  'AI is helping many industries grow faster and smarter. In healthcare, it helps doctors detect diseases early. In education, AI-powered tools make learning easier and more personalized. In agriculture, AI helps farmers monitor crops and improve production. Even in banking, transportation, and cybersecurity, AI plays a major role.',
#  'One of the biggest advantages of AI is that it can complete tasks faster, reduce human errors, and save time. It can analyze huge amounts of data within seconds and provide accurate results.',
#  'However, AI also has some challenges. Excessive dependence on AI may reduce human creativity and can affect jobs in certain sectors. Therefore, AI should be used responsibly and ethically for the betterment of society.',
#  'In my opinion, AI is not here to replace humans completely, but to assist humans and make our lives easier. The future of AI is very exciting, and it will continue to transform the world in many ways.',
#  'So, instead of fearing AI, we should learn about it, adapt to it, and use it wisely.',
#  'Thank you everyone. Have a great day!']

# %%
doc = splitter.create_documents(chunks)
print(doc[0])
# Out:
# page_content='Good Morning Everyone,'
