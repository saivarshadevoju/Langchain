# %% [markdown]
# # How to recursively split text by characters

# %% [markdown]
# This text splitter is the recommended one for generic text. It is parameterized by a list of characters. It tries to split on them in order until the chunks are small enough. The default list is ["\n\n", "\n", " ", ""]. This has the effect of trying to keep all paragraphs (and then sentences, and then words) together as long as possible, as those would generically seem to be the strongest semantically related pieces of text.
#
# Meaning:
# First try splitting by paragraphs (\n\n)
# If chunks are still too big, split by new lines (\n)
# If still big, split by spaces ( )
# Finally split by characters ("")
#
# • How the text is split: by list of characters.
# • How the chunk size is measured: by number of characters.

# %%
## Reading a PDF File

from langchain_community.document_loaders import PyPDFLoader
pdf_loader = PyPDFLoader('Paper ID_631.pdf')
pdf = pdf_loader.load()
pdf
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-04-15T12:15:38+05:30', 'author': 'Markus Richter', 'moddate': '2026-04-15T12:15:38+05:30', 'source': 'Paper ID_631.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1'}, page_content='Optimization Based Plant Disease Detection and \nSoil Health Monitoring in Smart Agriculture \nusing Deep Learning Techniques \nPuranam Revanth Kumar1[0000-0002-9141-9901], Devoju Sai Varsha1, Varshitha Doddavula1, \nDevarakonda Shivani1, Cherukuri Subashini1 \n1Department of Artificial Intelligence and Machine Learning, School of Engineering, \nMalla Reddy University, Hyderabad, India. \nrevanth123451.rk@gmail.com   \nAbstract. Smart agriculture has become essential for improving crop yield and maintaining \nsoil quality through timely disease detection and soil health monitoring. Traditional methods \nfor plant disease identification and soil assessment are often time-consuming, labor-inte
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=200)
final_documents = text_splitter.split_documents(pdf)
final_documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-04-15T12:15:38+05:30', 'author': 'Markus Richter', 'moddate': '2026-04-15T12:15:38+05:30', 'source': 'Paper ID_631.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1'}, page_content='Optimization Based Plant Disease Detection and \nSoil Health Monitoring in Smart Agriculture \nusing Deep Learning Techniques \nPuranam Revanth Kumar1[0000-0002-9141-9901], Devoju Sai Varsha1, Varshitha Doddavula1, \nDevarakonda Shivani1, Cherukuri Subashini1 \n1Department of Artificial Intelligence and Machine Learning, School of Engineering, \nMalla Reddy University, Hyderabad, India. \nrevanth123451.rk@gmail.com'),
# ...

# %%
print(final_documents[0])
# Out:
# page_content='Optimization Based Plant Disease Detection and
# Soil Health Monitoring in Smart Agriculture
# using Deep Learning Techniques
# Puranam Revanth Kumar1[0000-0002-9141-9901], Devoju Sai Varsha1, Varshitha Doddavula1,
# Devarakonda Shivani1, Cherukuri Subashini1
# 1Department of Artificial Intelligence and Machine Learning, School of Engineering,
# Malla Reddy University, Hyderabad, India.
# revanth123451.rk@gmail.com' metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-04-15T12:15:38+05:30', 'author': 'Markus Richter', 'moddate': '2026-04-15T12:15:38+05:30', 'source': 'Paper ID_631.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1'}

# %%
print(final_documents[1])
# Out:
# page_content='1Department of Artificial Intelligence and Machine Learning, School of Engineering,
# Malla Reddy University, Hyderabad, India.
# revanth123451.rk@gmail.com
# Abstract. Smart agriculture has become essential for improving crop yield and maintaining
# soil quality through timely disease detection and soil health monitoring. Traditional methods
# for plant disease identification and soil assessment are often time-consuming, labor-intensive,' metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-04-15T12:15:38+05:30', 'author': 'Markus Richter', 'moddate': '2026-04-15T12:15:38+05:30', 'source': 'Paper ID_631.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1'}

# %%
## Text Loader

from langchain_community.document_loaders import TextLoader
loader = TextLoader('speech.txt')
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Good Morning Everyone,\n\nMy name is Sai Varsha, and today I am going to speak about Artificial Intelligence, commonly known as AI.\n\nArtificial Intelligence is one of the most powerful and rapidly growing technologies in the world today. AI refers to machines or computer systems that can perform tasks which usually require human intelligence, such as learning, problem-solving, decision-making, speech recognition, and image understanding.\n\nToday, AI is becoming a part of our daily lives. When we use voice assistants like Google Assistant or Siri, get recommendations on Netflix or YouTube, or use navigation apps like Google Maps, we are actually using AI.\n\nAI is helping many industries grow faster and smarter. In healthcare, it helps doctors detect diseases early. In education, AI-powered tools make learning easier and more personalized. In agriculture, AI helps farmers monitor crops and improve production. Even in bankin
# ...

# %%
with open('speech.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Good Morning Everyone,
#
# My name is Sai Varsha, and today I am going to speak about Artificial Intelligence, commonly known as AI.
#
# Artificial Intelligence is one of the most powerful and rapidly growing technologies in the world today. AI refers to machines or computer systems that can perform tasks which usually require human intelligence, such as learning, problem-solving, decision-making, speech recognition, and image understanding.
#
# Today, AI is becoming a part of our daily lives. When we use voice assistants like Google Assistant or Siri, get recommendations on Netflix or YouTube, or use navigation apps like Google Maps, we are actually using AI.
#
# ...

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
final_docs = text_splitter.create_documents([content])
print(final_docs[0])
print(final_docs[1])
# Out:
# page_content='Good Morning Everyone,'
# page_content='My name is Sai Varsha, and today I am going to speak about Artificial Intelligence, commonly known'

# %%
type(final_docs[0])
# Out:
# langchain_core.documents.base.Document
