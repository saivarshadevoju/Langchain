# %% [markdown]
# # How to split JSON Data

# %% [markdown]
# This json splitter splits json data while allowing control over chunk sizes. It traverses json data depth first and builds smaller json chunks. It attempts to keep nested json objects whole but will split them if needed to keep chunks between a min_chunk_size and the max_chunk_size.
#
# If the value is not a nested json, but rather a very large string the string will not be split. If you need a hard cap on the chunk size consider composing this with a Recursive Text splitter on those chunks. There is an optional pre-processing step to split lists, by first converting them to json (dict) and then splitting them as such.
#
# * How the text is split: json value.
# * How the chunk size is measured: by number of characters.

# %%
json_data = {
  "company": {
    "name": "FutureVision Analytics",
    "industry": "Artificial Intelligence and Data Solutions",
    "founded": 2018,
    "headquarters": {
      "city": "Hyderabad",
      "country": "India"
    },
    "departments": [
      {
        "department_id": "D101",
        "name": "Research and Development",
        "manager": "Ananya Rao",
        "employees": [
          {
            "employee_id": "E001",
            "name": "Rahul Sharma",
            "role": "Machine Learning Engineer",
            "skills": [
              "Python",
              "TensorFlow",
              "PyTorch",
              "Deep Learning",
              "Natural Language Processing"
            ],
            "projects": [
              {
                "project_id": "P1001",
                "title": "AI Chatbot for Customer Support",
                "status": "Completed",
                "description": "Developed an AI-powered conversational assistant capable of handling customer queries, ticket generation, and multilingual support for enterprise clients.",
                "technologies": [
                  "LangChain",
                  "OpenAI API",
                  "FastAPI",
                  "MongoDB"
                ]
              },
              {
                "project_id": "P1002",
                "title": "Document Intelligence Platform",
                "status": "In Progress",
                "description": "Created a retrieval-augmented generation system to process legal and healthcare documents using embeddings and vector databases.",
                "technologies": [
                  "FAISS",
                  "Transformers",
                  "HuggingFace",
                  "Docker"
                ]
              }
            ]
          },
          {
            "employee_id": "E002",
            "name": "Sneha Patel",
            "role": "Data Scientist",
            "skills": [
              "Data Analysis",
              "SQL",
              "Power BI",
              "Statistics",
              "Visualization"
            ],
            "projects": [
              {
                "project_id": "P1003",
                "title": "Sales Forecasting Dashboard",
                "status": "Completed",
                "description": "Built a predictive dashboard that analyzes seasonal sales patterns, customer trends, and revenue forecasting for retail businesses.",
                "technologies": [
                  "Power BI",
                  "Pandas",
                  "Scikit-learn",
                  "PostgreSQL"
                ]
              }
            ]
          }
        ]
      },
      {
        "department_id": "D102",
        "name": "Cloud Infrastructure",
        "manager": "Vikram Reddy",
        "employees": [
          {
            "employee_id": "E003",
            "name": "Ayesha Khan",
            "role": "DevOps Engineer",
            "skills": [
              "AWS",
              "Docker",
              "Kubernetes",
              "CI/CD",
              "Linux"
            ],
            "projects": [
              {
                "project_id": "P1004",
                "title": "Automated Deployment Pipeline",
                "status": "Completed",
                "description": "Designed and deployed scalable CI/CD pipelines to automate testing, deployment, and monitoring of enterprise applications.",
                "technologies": [
                  "GitHub Actions",
                  "Jenkins",
                  "Kubernetes",
                  "Terraform"
                ]
              }
            ]
          }
        ]
      }
    ],
    "clients": [
      {
        "client_id": "C001",
        "name": "HealthSync Hospitals",
        "services_used": [
          "AI Diagnostics",
          "Medical Document Search",
          "Patient Chat Assistant"
        ],
        "feedback": {
          "rating": 4.8,
          "comments": "The AI solutions significantly improved operational efficiency and patient response times."
        }
      },
      {
        "client_id": "C002",
        "name": "RetailNova",
        "services_used": [
          "Demand Forecasting",
          "Customer Analytics",
          "Sales Dashboard"
        ],
        "feedback": {
          "rating": 4.6,
          "comments": "The predictive dashboards helped optimize inventory management and improve revenue growth."
        }
      }
    ],
    "training_programs": [
      {
        "program_id": "T001",
        "title": "Generative AI Bootcamp",
        "duration_weeks": 8,
        "topics": [
          "Transformers",
          "Prompt Engineering",
          "RAG Pipelines",
          "Fine-tuning",
          "LangChain"
        ],
        "participants": 120
      },
      {
        "program_id": "T002",
        "title": "Data Analytics Masterclass",
        "duration_weeks": 6,
        "topics": [
          "Excel",
          "SQL",
          "Python",
          "Power BI",
          "Data Cleaning"
        ],
        "participants": 200
      }
    ],
    "annual_report": {
      "year": 2025,
      "revenue_million_usd": 12.5,
      "growth_percentage": 28,
      "key_highlights": [
        "Expanded AI research team by 40 percent",
        "Launched enterprise document intelligence platform",
        "Partnered with international healthcare providers",
        "Improved cloud infrastructure scalability by 60 percent"
      ],
      "future_goals": [
        "Build multimodal AI systems",
        "Expand into European markets",
        "Develop low-cost AI tools for education",
        "Invest in sustainable cloud technologies"
      ]
    }
  }
}

# %%
from langchain_text_splitters import RecursiveJsonSplitter
json_splitter = RecursiveJsonSplitter(max_chunk_size=300)
json_chunks = json_splitter.split_json(json_data)

# %%
json_chunks[0]
# Out:
# {'company': {'name': 'FutureVision Analytics',
#   'industry': 'Artificial Intelligence and Data Solutions',
#   'founded': 2018,
#   'headquarters': {'city': 'Hyderabad', 'country': 'India'}}}

# %%
json_chunks[1]
# Out:
# {'company': {'departments': [{'department_id': 'D101',
#     'name': 'Research and Development',
#     'manager': 'Ananya Rao',
#     'employees': [{'employee_id': 'E001',
#       'name': 'Rahul Sharma',
#       'role': 'Machine Learning Engineer',
#       'skills': ['Python',
#        'TensorFlow',
#        'PyTorch',
#        'Deep Learning',
#        'Natural Language Processing'],
#       'projects': [{'project_id': 'P1001',
#         'title': 'AI Chatbot for Customer Support',
#         'status': 'Completed',
#         'description': 'Developed an AI-powered conversational assistant capable of handling customer queries, ticket generation, and multilingual support for enterprise clients.',
#         'technologies': ['LangChain', 'OpenAI API', 'FastAPI', 'MongoDB']},
#        {'project_id': 'P1002',
#         'title': 'Document Intelligence Platform',
#         'status': 'In Progress',
# ...

# %%
for chunk in json_chunks[:3]:
    print(chunk)
# Out:
# {'company': {'name': 'FutureVision Analytics', 'industry': 'Artificial Intelligence and Data Solutions', 'founded': 2018, 'headquarters': {'city': 'Hyderabad', 'country': 'India'}}}
# ...

# %%
# This splitter can also output documents

docs = json_splitter.create_documents(texts=[json_data])
docs[0]
# Out:
# Document(metadata={}, page_content='{"company": {"name": "FutureVision Analytics", "industry": "Artificial Intelligence and Data Solutions", "founded": 2018, "headquarters": {"city": "Hyderabad", "country": "India"}}}')

# %%
texts = json_splitter.split_json(json_data)
texts[0]
# Out:
# {'company': {'name': 'FutureVision Analytics',
#   'industry': 'Artificial Intelligence and Data Solutions',
#   'founded': 2018,
#   'headquarters': {'city': 'Hyderabad', 'country': 'India'}}}

# %%
texts = json_splitter.split_text(json_data)
texts[0]
# Out:
# '{"company": {"name": "FutureVision Analytics", "industry": "Artificial Intelligence and Data Solutions", "founded": 2018, "headquarters": {"city": "Hyderabad", "country": "India"}}}'
